# %%
# load libraries
library(MotifDb)
library(seqLogo)
# Out:
# Lade nötiges Paket: BiocGenerics
#
#
# Attache Paket: ‘BiocGenerics’
#
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Lade nötiges Paket: S4Vectors
#
# Lade nötiges Paket: stats4
#
#
# Attache Paket: ‘S4Vectors’
#
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
#
# Lade nötiges Paket: IRanges
#
# Lade nötiges Paket: GenomicRanges
#
# Lade nötiges Paket: GenomeInfoDb
#
# Lade nötiges Paket: Biostrings
#
# ...

# %%
sessionInfo()
# Out:
# R version 4.2.2 (2022-10-31)
# Platform: x86_64-apple-darwin17.0 (64-bit)
# Running under: macOS Catalina 10.15.7
#
# Matrix products: default
# BLAS:   /Library/Frameworks/R.framework/Versions/4.2/Resources/lib/libRblas.0.dylib
# LAPACK: /Library/Frameworks/R.framework/Versions/4.2/Resources/lib/libRlapack.dylib
#
# locale:
# [1] C/UTF-8/C/C/C/C
#
# attached base packages:
# [1] grid      stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
# [1] seqLogo_1.64.0       MotifDb_1.40.0       Biostrings_2.66.0
# [4] XVector_0.38.0       GenomicRanges_1.50.2 GenomeInfoDb_1.34.9
# [7] IRanges_2.32.0       S4Vectors_0.36.2     BiocGenerics_0.44.0
#
# loaded via a namespace (and not attached):
#  [1] pillar_1.9.0                compiler_4.2.2
#  [3] restfulr_0.0.15             MatrixGenerics_1.10.0
#  [5] bitops_1.0-7                base64enc_0.1-3
#  [7] tools_4.2.2                 zlibbioc_1.44.0
# ...

# %%
query(MotifDb,"ETS1")
# Out:
# MotifDb object of length 20
# | Created from downloaded public sources, last update: 2022-Mar-04
# | 20 position frequency matrices from 11 sources:
# |        HOCOMOCOv10:    2
# | HOCOMOCOv11-core-A:    1
# |              HOMER:    2
# |        JASPAR_2014:    1
# |        JASPAR_CORE:    1
# |       SwissRegulon:    1
# |               hPDI:    1
# |         jaspar2016:    3
# |         jaspar2018:    3
# |         jaspar2022:    1
# |          jolma2013:    4
# | 3 organism/s
# |           Hsapiens:   14
# |          Mmusculus:    4
# |              other:    2
# Hsapiens-SwissRegulon-ETS1.SwissRegulon
# Hsapiens-hPDI-ETS1
# Hsapiens-HOCOMOCOv10-ETS1_HUMAN.H10MO.C
# Mmusculus-HOCOMOCOv10-ETS1_MOUSE.H10MO.B
# Hsapiens-HOCOMOCOv11-core-A-ETS1_HUMAN.H11MO.0.A
# ...
# Hsapiens-jaspar2022-ETS1-MA0098.3
# Hsapiens-jolma2013-ETS1
# Hsapiens-jolma2013-ETS1-2
# Hsapiens-jolma2013-ETS1-3
# Hsapiens-jolma2013-ETS1-4

# %%
str(query(MotifDb,"ETS1"))
# Out:
# Formal class 'MotifList' [package "MotifDb"] with 5 slots
#   ..@ elementMetadata                         :Formal class 'DFrame' [package "S4Vectors"] with 6 slots
#   .. .. ..@ rownames       : chr [1:20] "Hsapiens-SwissRegulon-ETS1.SwissRegulon" "Hsapiens-hPDI-ETS1" "Hsapiens-HOCOMOCOv10-ETS1_HUMAN.H10MO.C" "Mmusculus-HOCOMOCOv10-ETS1_MOUSE.H10MO.B" ...
#   .. .. ..@ nrows          : int 20
#   .. .. ..@ elementType    : chr "ANY"
#   .. .. ..@ elementMetadata: NULL
#   .. .. ..@ metadata       : list()
#   .. .. ..@ listData       :List of 15
#   .. .. .. ..$ providerName   : chr [1:20] "ETS1.SwissRegulon" "ETS1" "ETS1_HUMAN.H10MO.C" "ETS1_MOUSE.H10MO.B" ...
#   .. .. .. ..$ providerId     : chr [1:20] "ETS1.SwissRegulon" "ETS1" "ETS1_HUMAN.H10MO.C" "ETS1_MOUSE.H10MO.B" ...
#   .. .. .. ..$ dataSource     : chr [1:20] "SwissRegulon" "hPDI" "HOCOMOCOv10" "HOCOMOCOv10" ...
#   .. .. .. ..$ geneSymbol     : chr [1:20] "ETS1" "ETS1" "ETS1" "ETS1" ...
# ...

# %%
pfm.ets1.hocomoco <- query(MotifDb,"ETS1")[[4]]
p <- seqLogo(pfm.ets1.hocomoco)

print(p)


dev.off()
pdf(file = "./ETS1_binding_motif_hocomoco.pdf"
   ,width = 8
   ,height = 3.5)
seqLogo(pfm.ets1.hocomoco)
dev.off()
# Out:
# NULL
# null device
#           1
# null device
#           1
# plot without title
